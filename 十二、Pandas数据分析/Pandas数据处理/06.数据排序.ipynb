# %%
import pandas as pd

df = pd.read_csv("../data/movies_info3.csv", nrows=10)
#根据上映时间升序排序
df.sort_values("上映时间",ascending=True)

#根据时常降序排序
df.sort_values("时常",ascending=False)

#先根据上映时间升序排序，相同的部分在根据评分降序
df.sort_values(["上映时间","评分"],ascending=[True,False])
# Out:
#                    电影名    年份        上映时间           类型   时常  评分     语言  \
# 6                   教父  1972  1972-03-24        剧情,犯罪  175  87     英语
# 9                  教父2  1974  1974-12-20        剧情,犯罪 -200  86     英语
# 4  鬼灭之刃：无限城篇 第一章 猗窝座再袭  2025  2025-11-14     动画,动作,奇幻  155  88     日语
# 1              不期而遇的姐妹  2026  2026-03-12        喜剧,爱情   85  89   西班牙语
# 8                 挽救计划  2026  2026-03-20        科幻,冒险  157  86     英语
# 7         迈克尔·杰克逊：巨星之路  2026  2026-04-24        音乐,剧情  136  87     英语
# 2              奇幻变身大冒险  2026  2026-05-01  冒险,动画,家庭,奇幻  102  89     英语
# 3                 夜巡毒枭  2026  2026-08-21     犯罪,动作,惊悚   91  88   西班牙语
# 5               肖申克的救赎  1994  2026-08-28        剧情,犯罪  142  87     英语
# 0           安昂传奇：最后的气宗  2026  2026/07/24  动画,动作,冒险,奇幻   99  92     英语
#
#                      导演             编剧                             宣传语  \
# 6                马里奥·普佐            NaN                     一份你无法拒绝的邀约。
# ...
