# %%
import pandas as pd

# 创建一个DataFrame表格
df = pd.DataFrame([
    {
        "姓名": "张三",
        "年龄": 20,
        "性别": "男",
        "地址": "北京市海淀区"
    },
    {
        "姓名": "李四",
        "年龄": 21,
        "性别": "男",
        "地址": "上海市浦东新区"
    },
    {
        "姓名": "王五",
        "年龄": 22,
        "性别": "男",
        "地址": "深圳市南山区"
    },
    {
        "姓名": "赵六",
        "年龄": 75,
        "性别": "男",
        "地址": "广州市天河区"
    }
])

series = df['姓名']

max_age = df['年龄'].max()
min_age = df['年龄'].min()
avg_age = df['年龄'].mean()
print(f"最大年龄: {max_age}, 最小年龄: {min_age}, 平均年龄: {avg_age:.2f}")
